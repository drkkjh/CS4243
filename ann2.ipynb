# %% [markdown]
# # function estimation using neural network

# %%
# example of fitting a neural net on x vs x^2
# %matplotlib inline

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from numpy import asarray
from matplotlib import pyplot

# %%
# define the dataset
#x = asarray([i for i in range(-50,51)])
x = np.arange(-10,10,0.05)
# y = asarray([i**3-2*i**2  for i in x ])
y = asarray([i**2  for i in x ])
print('minimum and maximum before normalization:' , x.min(), x.max(), y.min(), y.max())
# reshape arrays into into rows and cols
x = x.reshape((len(x), 1))
y = y.reshape((len(y), 1))
# separately scale the input and output variables
scale_x = MinMaxScaler()
x = scale_x.fit_transform(x)
scale_y = MinMaxScaler()
y = scale_y.fit_transform(y)
print('minimum and maximum after normalization:' , x.min(), x.max(), y.min(), y.max())
# Out:
# minimum and maximum before normalization: -10.0 9.950000000000284 2.0194839173657902e-26 100.0
# minimum and maximum after normalization: 0.0 1.0 0.0 1.0

# %% [markdown]
# ### ------------------------------------------
# To learn more about ANN in function estimation you may try these in the cell below:
#     1- structure 1x10x10x1 , with sigmoid, 800 training epochs
#     2- structure 1x10x10x1 , with relu, 800 training epochs
#     3- structure 1x10x10x1 , no activation function, 800 training epochs
#     4- structure 1x1x1x1 , with sigmoid or relu, 800 training epochs
#     5- structure 1x1x10x1 , with sigmoid or relu, 800 training epochs
#     6- structure 1x10x10x1 , with relu, 20 training epochs
#     7- structure 1x2x2x1 , with relu, 800 training epochs
# run each a few times to get sure about the results.

# %%
# design the neural network model
model = Sequential()
model.add(Dense(2, input_dim=1, activation='sigmoid'))
model.add(Dense(2, activation='sigmoid'))
model.add(Dense(1))
# define the loss function and optimization algorithm
model.compile(loss='mse', optimizer='adam')
# ft the model on the training dataset
model.fit(x, y, epochs=800, batch_size=10, verbose=1)
# make predictions for the input data
yhat = model.predict(x)
# Out:
# Epoch 1/800
# 40/40 [==============================] - 0s 667us/step - loss: 0.5544
# Epoch 2/800
# 40/40 [==============================] - 0s 641us/step - loss: 0.4054
# Epoch 3/800
# 40/40 [==============================] - 0s 641us/step - loss: 0.2991
# Epoch 4/800
# 40/40 [==============================] - 0s 641us/step - loss: 0.2269
# Epoch 5/800
# 40/40 [==============================] - 0s 666us/step - loss: 0.1773
# Epoch 6/800
# 40/40 [==============================] - 0s 667us/step - loss: 0.1447
# Epoch 7/800
# 40/40 [==============================] - 0s 667us/step - loss: 0.1233
# Epoch 8/800
# 40/40 [==============================] - 0s 641us/step - loss: 0.1095
# Epoch 9/800
# 40/40 [==============================] - 0s 641us/step - loss: 0.1010
# Epoch 10/800
# 40/40 [==============================] - 0s 615us/step - loss: 0.0959
# Epoch 11/800
# 40/40 [==============================] - 0s 641us/step - loss: 0.0926
# Epoch 12/800
# ...

# %%
# inverse transforms

x_plot = scale_x.inverse_transform(x)
y_plot = scale_y.inverse_transform(y)
yhat_plot = scale_y.inverse_transform(yhat)

# report model error
print('MSE::: %.3f' % mean_squared_error(y_plot, yhat_plot))
print('Root MSE::: %.3f' % mean_squared_error(y_plot, yhat_plot) **0.5)
print('MAE::: %.3f' % mean_absolute_error(y_plot, yhat_plot))
# plot x vs y
pyplot.scatter(x_plot,y_plot, label='Actual')
# plot x vs yhat
pyplot.scatter(x_plot,yhat_plot, label='Predicted')
pyplot.title('Input (x) versus Output (y)')
pyplot.xlabel('Input Variable (x)')
pyplot.ylabel('Output Variable (y)')
pyplot.legend()
pyplot.show()
# Out:
# MSE::: 3.881
# Root MSE::: 1.970
# MAE::: 1.665
